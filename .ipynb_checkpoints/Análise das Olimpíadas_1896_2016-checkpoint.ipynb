# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('athlete_events.csv')
region_df = pd.read_csv('noc_regions.csv')

# %%
df.info()
df.tail()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# ...

# %% [markdown]
# # Trabalhar só com eventos ocorridos no verão.

# %%
mask = df['Season'] == 'Summer'
df = df[mask]

# %%
region_df.head()
# Out:
#    NOC       region                 notes
# 0  AFG  Afghanistan                   NaN
# 1  AHO      Curacao  Netherlands Antilles
# 2  ALB      Albania                   NaN
# 3  ALG      Algeria                   NaN
# 4  AND      Andorra                   NaN

# %%
df = df.merge(region_df, on='NOC', how='left')

# %%
df['region'].nunique()
# Out:
# 205

# %%
df.isnull().sum()
# Out:
# ID             0
# Name           0
# Sex            0
# Age         9189
# Height     51857
# Weight     53854
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     188464
# region       370
# notes     218151
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1385

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Medal'].value_counts()
# Out:
# Gold      11456
# Bronze    11409
# Silver    11212
# Name: Medal, dtype: int64

# %%
pd.get_dummies(df['Medal'])
# Out:
#         Bronze  Gold  Silver
# 0            0     0       0
# 1            0     0       0
# 2            0     0       0
# 3            0     1       0
# 4            0     0       0
# ...        ...   ...     ...
# 222547       0     0       0
# 222548       0     0       0
# 222549       0     0       0
# 222550       0     0       0
# 222551       0     0       0
#
# [221167 rows x 3 columns]

# %%
df = pd.concat([df, pd.get_dummies(df['Medal'])], axis=1)

# %%
df.groupby('NOC').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Gold', ascending=False).reset_index().head(26)
# Out:
#     NOC    Gold  Silver  Bronze
# 0   USA  2472.0  1333.0  1197.0
# 1   URS   832.0   635.0   596.0
# 2   GBR   635.0   729.0   620.0
# 3   GER   592.0   538.0   649.0
# 4   ITA   518.0   474.0   454.0
# 5   FRA   463.0   567.0   587.0
# 6   HUN   432.0   328.0   363.0
# 7   SWE   354.0   396.0   358.0
# 8   AUS   342.0   452.0   510.0
# 9   GDR   339.0   277.0   227.0
# 10  CHN   334.0   317.0   258.0
# 11  RUS   296.0   278.0   331.0
# 12  NED   245.0   302.0   371.0
# 13  JPN   230.0   287.0   333.0
# 14  NOR   227.0   196.0   167.0
# 15  DEN   179.0   236.0   177.0
# 16  KOR   171.0   206.0   175.0
# 17  CUB   164.0   129.0   116.0
# 18  ROU   161.0   200.0   290.0
# 19  CAN   158.0   239.0   344.0
# 20  FRG   144.0   172.0   188.0
# 21  FIN   132.0   125.0   217.0
# 22  IND   131.0    19.0    40.0
# 23  YUG   130.0   161.0    92.0
# 24  POL   111.0   185.0   242.0
# 25  BRA   109.0   175.0   191.0

# %%
mask1 = (df['NOC'] == 'BRA') & (df['Medal'] == 'Gold')
df[mask1]
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 1433       925  Adenzia Aparecida Ferreira da Silva   F  25.0   187.0    65.0
# 4275      2758                 Alison Conte Cerutti   M  30.0   203.0   106.0
# 5236      3330                       Amauri Ribeiro   M  33.0   198.0    87.0
# 5931      3790       Anderson de Oliveira Rodrigues   M  30.0   190.0    95.0
# 7921      5093               William Peixoto Arjona   M  37.0   186.0    78.0
# ...        ...                                  ...  ..   ...     ...     ...
# 212511  129573                     Alexander Welter   M  27.0   186.0    75.0
# 213022  129899             Wverton Pereira da Silva   M  28.0   189.0    86.0
# 214214  130541           William de Asevedo Furtado   M  21.0   176.0    65.0
# 219977  133931             Arthur Nabarrete Zanetti   M  22.0   156.0    61.0
# 220386  134211               Jos Carlos Cracco Neto   M  22.0   170.0    69.0
#
# ...

# %%
medal_tally = df.drop_duplicates(subset=['Team', 'NOC', 'Games', 'Year', 'City', 'Sport', 'Event', 'Medal'])
medal_tally = medal_tally.groupby('NOC').sum()[['Gold', 'Silver', 'Bronze']].sort_values('Gold', ascending=False).reset_index()

# %%
medal_tally[medal_tally['NOC'] == 'BRA']
# Out:
#     NOC  Gold  Silver  Bronze
# 34  BRA  30.0    36.0    62.0

# %% [markdown]
# #parei no tempo 32:26
